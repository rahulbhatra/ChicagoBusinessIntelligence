# %%
import pandas as pd

# %%
zipCodeCommunityArea = pd.read_excel('ZipCodeCommunityArea.xlsx')
# for i in range(len(zipCodeCommunityArea)):
#     print(zipCodeCommunityArea.loc[i])

# %%
communityAreaNumberName = pd.read_excel('CommunityAreaNumberName.xlsx')
# print(communityAreaNumberName)

# %%
data = []
for i in range(len(zipCodeCommunityArea)):
    zipCode = zipCodeCommunityArea.loc[i, 'Zip Code']
    communityAreas = zipCodeCommunityArea.loc[i, 'Community Area'].split(",")
#     print(zipCode, communityAreas)
    for j in range(len(communityAreaNumberName)):
        areaNumber = communityAreaNumberName.loc[j, 'AREA_NUMBE']
        community = communityAreaNumberName.loc[j, 'COMMUNITY']
        for communityArea in communityAreas:
            if communityArea.lower().replace(" ", "") == community.lower().replace(" ", ""):
                print("Area Number", areaNumber, "Community", community, "ZipCode" , zipCode, "ZipCode Community", communityArea)
                data.append([areaNumber, community, zipCode])
                
data = sorted(data)
for i in range(len(data)):
    print(data[i])
    
print(len(data))
# Out:
# Area Number 32 Community LOOP ZipCode 60601 ZipCode Community Loop
# Area Number 32 Community LOOP ZipCode 60602 ZipCode Community Loop
# Area Number 32 Community LOOP ZipCode 60603 ZipCode Community Loop
# Area Number 32 Community LOOP ZipCode 60604 ZipCode Community Loop
# Area Number 32 Community LOOP ZipCode 60605 ZipCode Community Loop
# Area Number 33 Community NEAR SOUTH SIDE ZipCode 60605 ZipCode Community  Near South Side
# Area Number 28 Community NEAR WEST SIDE ZipCode 60606 ZipCode Community  Near West Side
# Area Number 32 Community LOOP ZipCode 60606 ZipCode Community Loop
# Area Number 28 Community NEAR WEST SIDE ZipCode 60607 ZipCode Community  Near West Side
# Area Number 32 Community LOOP ZipCode 60607 ZipCode Community Loop
# Area Number 33 Community NEAR SOUTH SIDE ZipCode 60607 ZipCode Community  Near South Side
# Area Number 28 Community NEAR WEST SIDE ZipCode 60608 ZipCode Community  Near West Side
# Area Number 29 Community NORTH LAWNDALE ZipCode 60608 ZipCode Community  North Lawndale
# Area Number 30 Community SOUTH LAWNDALE ZipCode 60608 ZipCode Community  South Lawndale
# Area Number 31 Community LOWER WEST SIDE ZipCode 60608 ZipCode Community  Lower West Side
# Area Number 59 Community MCKINLEY PARK ZipCode 60608 ZipCode Community  McKinley Park
# Area Number 60 Community BRIDGEPORT ZipCode 60608 ZipCode Community Bridgeport
# Area Number 34 Community ARMOUR SQUARE ZipCode 60609 ZipCode Community Armour Square
# Area Number 35 Community DOUGLAS ZipCode 60609 ZipCode Community  Douglas
# Area Number 37 Community FULLER PARK ZipCode 60609 ZipCode Community  Fuller Park
# Area Number 38 Community GRAND BOULEVARD ZipCode 60609 ZipCode Community  Grand Boulevard
# Area Number 40 Community WASHINGTON PARK ZipCode 60609 ZipCode Community  Washington Park
# Area Number 59 Community MCKINLEY PARK ZipCode 60609 ZipCode Community  McKinley Park
# Area Number 60 Community BRIDGEPORT ZipCode 60609 ZipCode Community  Bridgeport
# Area Number 61 Community NEW CITY ZipCode 60609 ZipCode Community  New City
# Area Number 63 Community GAGE PARK ZipCode 60609 ZipCode Community  Gage Park
# Area Number 8 Community NEAR NORTH SIDE ZipCode 60610 ZipCode Community Near North Side
# Area Number 28 Community NEAR WEST SIDE ZipCode 60610 ZipCode Community  Near West Side
# Area Number 8 Community NEAR NORTH SIDE ZipCode 60611 ZipCode Community Near North Side
# Area Number 24 Community WEST TOWN ZipCode 60612 ZipCode Community  West Town
# Area Number 28 Community NEAR WEST SIDE ZipCode 60612 ZipCode Community Near West Side
# Area Number 3 Community UPTOWN ZipCode 60613 ZipCode Community  Uptown
# Area Number 5 Community NORTH CENTER ZipCode 60613 ZipCode Community  North Center
# Area Number 6 Community LAKE VIEW ZipCode 60613 ZipCode Community Lakeview
# Area Number 7 Community LINCOLN PARK ZipCode 60614 ZipCode Community Lincoln Park
# Area Number 22 Community LOGAN SQUARE ZipCode 60614 ZipCode Community  Logan Square
# Area Number 38 Community GRAND BOULEVARD ZipCode 60615 ZipCode Community Grand Boulevard
# Area Number 39 Community KENWOOD ZipCode 60615 ZipCode Community  Kenwood
# Area Number 40 Community WASHINGTON PARK ZipCode 60615 ZipCode Community  Washington Park
# Area Number 41 Community HYDE PARK ZipCode 60615 ZipCode Community  Hyde Park
# Area Number 31 Community LOWER WEST SIDE ZipCode 60616 ZipCode Community Lower West Side
# Area Number 33 Community NEAR SOUTH SIDE ZipCode 60616 ZipCode Community  Near South Side
# Area Number 34 Community ARMOUR SQUARE ZipCode 60616 ZipCode Community Armour Square
# Area Number 35 Community DOUGLAS ZipCode 60616 ZipCode Community  Douglas
# Area Number 60 Community BRIDGEPORT ZipCode 60616 ZipCode Community  Bridgeport
# Area Number 45 Community AVALON PARK ZipCode 60617 ZipCode Community Avalon Park
# Area Number 46 Community SOUTH CHICAGO ZipCode 60617 ZipCode Community  South Chicago
# Area Number 48 Community CALUMET HEIGHTS ZipCode 60617 ZipCode Community  Calumet Heights
# Area Number 51 Community SOUTH DEERING ZipCode 60617 ZipCode Community  South Deering
# Area Number 52 Community EAST SIDE ZipCode 60617 ZipCode Community  East Side
# Area Number 5 Community NORTH CENTER ZipCode 60618 ZipCode Community  North Center
# Area Number 16 Community IRVING PARK ZipCode 60618 ZipCode Community  Irving Park
# Area Number 21 Community AVONDALE ZipCode 60618 ZipCode Community Avondale
# Area Number 43 Community SOUTH SHORE ZipCode 60619 ZipCode Community  South Shore
# Area Number 44 Community CHATHAM ZipCode 60619 ZipCode Community  Chatham
# Area Number 45 Community AVALON PARK ZipCode 60619 ZipCode Community Avalon Park
# Area Number 47 Community BURNSIDE ZipCode 60619 ZipCode Community  Burnside
# Area Number 48 Community CALUMET HEIGHTS ZipCode 60619 ZipCode Community  Calumet Heights
# Area Number 49 Community ROSELAND ZipCode 60619 ZipCode Community  Roseland
# Area Number 69 Community GREATER GRAND CROSSING ZipCode 60619 ZipCode Community  Greater Grand Crossing
# Area Number 44 Community CHATHAM ZipCode 60620 ZipCode Community  Chatham
# Area Number 49 Community ROSELAND ZipCode 60620 ZipCode Community  Roseland
# Area Number 69 Community GREATER GRAND CROSSING ZipCode 60620 ZipCode Community  Greater Grand Crossing
# Area Number 71 Community AUBURN GRESHAM ZipCode 60620 ZipCode Community Auburn Gresham
# Area Number 72 Community BEVERLY ZipCode 60620 ZipCode Community  Beverly
# Area Number 73 Community WASHINGTON HEIGHTS ZipCode 60620 ZipCode Community  Washington Heights
# Area Number 40 Community WASHINGTON PARK ZipCode 60621 ZipCode Community  Washington Park
# Area Number 68 Community ENGLEWOOD ZipCode 60621 ZipCode Community Englewood
# Area Number 69 Community GREATER GRAND CROSSING ZipCode 60621 ZipCode Community  Greater Grand Crossing
# Area Number 8 Community NEAR NORTH SIDE ZipCode 60622 ZipCode Community  Near North Side
# Area Number 22 Community LOGAN SQUARE ZipCode 60622 ZipCode Community  Logan Square
# Area Number 23 Community HUMBOLDT PARK ZipCode 60622 ZipCode Community Humboldt Park
# Area Number 24 Community WEST TOWN ZipCode 60622 ZipCode Community  West Town
# Area Number 29 Community NORTH LAWNDALE ZipCode 60623 ZipCode Community North Lawndale
# Area Number 30 Community SOUTH LAWNDALE ZipCode 60623 ZipCode Community  South Lawndale
# Area Number 23 Community HUMBOLDT PARK ZipCode 60624 ZipCode Community  Humboldt Park
# Area Number 26 Community WEST GARFIELD PARK ZipCode 60624 ZipCode Community  West Garfield Park
# Area Number 27 Community EAST GARFIELD PARK ZipCode 60624 ZipCode Community East Garfield Park
# Area Number 29 Community NORTH LAWNDALE ZipCode 60624 ZipCode Community  North Lawndale
# Area Number 4 Community LINCOLN SQUARE ZipCode 60625 ZipCode Community  Lincoln Square
# Area Number 13 Community NORTH PARK ZipCode 60625 ZipCode Community  North Park
# Area Number 14 Community ALBANY PARK ZipCode 60625 ZipCode Community Albany Park
# Area Number 1 Community ROGERS PARK ZipCode 60626 ZipCode Community Rogers Park
# Area Number 49 Community ROSELAND ZipCode 60628 ZipCode Community  Roseland
# Area Number 50 Community PULLMAN ZipCode 60628 ZipCode Community Pullman
# Area Number 53 Community WEST PULLMAN ZipCode 60628 ZipCode Community  West Pullman
# Area Number 73 Community WASHINGTON HEIGHTS ZipCode 60628 ZipCode Community  Washington Heights
# Area Number 56 Community GARFIELD RIDGE ZipCode 60629 ZipCode Community  Garfield Ridge
# Area Number 62 Community WEST ELSDON ZipCode 60629 ZipCode Community  West Elsdon
# Area Number 63 Community GAGE PARK ZipCode 60629 ZipCode Community  Gage Park
# Area Number 64 Community CLEARING ZipCode 60629 ZipCode Community  Clearing
# Area Number 65 Community WEST LAWN ZipCode 60629 ZipCode Community  West Lawn
# Area Number 66 Community CHICAGO LAWN ZipCode 60629 ZipCode Community Chicago Lawn
# Area Number 11 Community JEFFERSON PARK ZipCode 60630 ZipCode Community  Jefferson Park
# Area Number 12 Community FOREST GLEN ZipCode 60630 ZipCode Community  Forest Glen
# Area Number 14 Community ALBANY PARK ZipCode 60630 ZipCode Community Albany Park
# Area Number 15 Community PORTAGE PARK ZipCode 60630 ZipCode Community  Portage Park
# Area Number 16 Community IRVING PARK ZipCode 60630 ZipCode Community  Irving Park
# Area Number 9 Community EDISON PARK ZipCode 60631 ZipCode Community Edison Park
# Area Number 10 Community NORWOOD PARK ZipCode 60631 ZipCode Community  Norwood Park
# Area Number 56 Community GARFIELD RIDGE ZipCode 60632 ZipCode Community  Garfield Ridge
# Area Number 57 Community ARCHER HEIGHTS ZipCode 60632 ZipCode Community Archer Heights
# Area Number 58 Community BRIGHTON PARK ZipCode 60632 ZipCode Community  Brighton Park
# Area Number 62 Community WEST ELSDON ZipCode 60632 ZipCode Community  West Elsdon
# Area Number 63 Community GAGE PARK ZipCode 60632 ZipCode Community  Gage Park
# Area Number 51 Community SOUTH DEERING ZipCode 60633 ZipCode Community  South Deering
# Area Number 55 Community HEGEWISCH ZipCode 60633 ZipCode Community Hegewisch
# Area Number 15 Community PORTAGE PARK ZipCode 60634 ZipCode Community  Portage Park
# Area Number 17 Community DUNNING ZipCode 60634 ZipCode Community  Dunning
# Area Number 18 Community MONTCLARE ZipCode 60634 ZipCode Community  Montclare
# Area Number 19 Community BELMONT CRAGIN ZipCode 60634 ZipCode Community Belmont Cragin
# Area Number 17 Community DUNNING ZipCode 60635 ZipCode Community  Dunning
# Area Number 18 Community MONTCLARE ZipCode 60635 ZipCode Community  Montclare
# Area Number 19 Community BELMONT CRAGIN ZipCode 60635 ZipCode Community  Belmont Cragin
# Area Number 25 Community AUSTIN ZipCode 60635 ZipCode Community Austin
# Area Number 63 Community GAGE PARK ZipCode 60636 ZipCode Community  Gage Park
# Area Number 66 Community CHICAGO LAWN ZipCode 60636 ZipCode Community Chicago Lawn
# Area Number 67 Community WEST ENGLEWOOD ZipCode 60636 ZipCode Community  West Englewood
# Area Number 40 Community WASHINGTON PARK ZipCode 60637 ZipCode Community  Washington Park
# Area Number 41 Community HYDE PARK ZipCode 60637 ZipCode Community  Hyde Park
# Area Number 42 Community WOODLAWN ZipCode 60637 ZipCode Community  Woodlawn
# Area Number 43 Community SOUTH SHORE ZipCode 60637 ZipCode Community  South Shore
# Area Number 69 Community GREATER GRAND CROSSING ZipCode 60637 ZipCode Community Greater Grand Crossing
# Area Number 56 Community GARFIELD RIDGE ZipCode 60638 ZipCode Community  Garfield Ridge
# Area Number 64 Community CLEARING ZipCode 60638 ZipCode Community Clearing
# Area Number 19 Community BELMONT CRAGIN ZipCode 60639 ZipCode Community  Belmont Cragin
# Area Number 20 Community HERMOSA ZipCode 60639 ZipCode Community  Hermosa
# Area Number 22 Community LOGAN SQUARE ZipCode 60639 ZipCode Community  Logan Square
# Area Number 23 Community HUMBOLDT PARK ZipCode 60639 ZipCode Community  Humboldt Park
# Area Number 25 Community AUSTIN ZipCode 60639 ZipCode Community Austin
# Area Number 3 Community UPTOWN ZipCode 60640 ZipCode Community  Uptown
# Area Number 4 Community LINCOLN SQUARE ZipCode 60640 ZipCode Community  Lincoln Square
# Area Number 77 Community EDGEWATER ZipCode 60640 ZipCode Community Edgewater
# Area Number 15 Community PORTAGE PARK ZipCode 60641 ZipCode Community  Portage Park
# Area Number 16 Community IRVING PARK ZipCode 60641 ZipCode Community  Irving Park
# Area Number 19 Community BELMONT CRAGIN ZipCode 60641 ZipCode Community  Belmont Cragin
# Area Number 20 Community HERMOSA ZipCode 60641 ZipCode Community  Hermosa
# Area Number 21 Community AVONDALE ZipCode 60641 ZipCode Community Avondale
# Area Number 72 Community BEVERLY ZipCode 60642 ZipCode Community Beverly
# Area Number 53 Community WEST PULLMAN ZipCode 60643 ZipCode Community  West Pullman
# Area Number 72 Community BEVERLY ZipCode 60643 ZipCode Community Beverly
# Area Number 73 Community WASHINGTON HEIGHTS ZipCode 60643 ZipCode Community  Washington Heights
# Area Number 75 Community MORGAN PARK ZipCode 60643 ZipCode Community  Morgan Park
# Area Number 25 Community AUSTIN ZipCode 60644 ZipCode Community Austin
# Area Number 2 Community WEST RIDGE ZipCode 60645 ZipCode Community West Ridge
# Area Number 10 Community NORWOOD PARK ZipCode 60646 ZipCode Community  Norwood Park
# Area Number 11 Community JEFFERSON PARK ZipCode 60646 ZipCode Community  Jefferson Park
# Area Number 12 Community FOREST GLEN ZipCode 60646 ZipCode Community Forest Glen
# Area Number 13 Community NORTH PARK ZipCode 60646 ZipCode Community  North Park
# Area Number 20 Community HERMOSA ZipCode 60647 ZipCode Community Hermosa
# Area Number 22 Community LOGAN SQUARE ZipCode 60647 ZipCode Community  Logan Square
# Area Number 23 Community HUMBOLDT PARK ZipCode 60647 ZipCode Community  Humboldt Park
# Area Number 24 Community WEST TOWN ZipCode 60647 ZipCode Community  West Town
# Area Number 43 Community SOUTH SHORE ZipCode 60649 ZipCode Community South Shore
# Area Number 23 Community HUMBOLDT PARK ZipCode 60651 ZipCode Community  Humboldt Park
# Area Number 25 Community AUSTIN ZipCode 60651 ZipCode Community Austin
# Area Number 70 Community ASHBURN ZipCode 60652 ZipCode Community Ashburn
# Area Number 35 Community DOUGLAS ZipCode 60653 ZipCode Community Douglas
# Area Number 36 Community OAKLAND ZipCode 60653 ZipCode Community  Oakland
# Area Number 38 Community GRAND BOULEVARD ZipCode 60653 ZipCode Community  Grand Boulevard
# Area Number 39 Community KENWOOD ZipCode 60653 ZipCode Community  Kenwood
# Area Number 72 Community BEVERLY ZipCode 60655 ZipCode Community Beverly
# Area Number 74 Community MOUNT GREENWOOD ZipCode 60655 ZipCode Community  Mount Greenwood
# Area Number 75 Community MORGAN PARK ZipCode 60655 ZipCode Community  Morgan Park
# Area Number 76 Community OHARE ZipCode 60656 ZipCode Community OHare
# Area Number 5 Community NORTH CENTER ZipCode 60657 ZipCode Community  North Center
# Area Number 6 Community LAKE VIEW ZipCode 60657 ZipCode Community Lakeview
# Area Number 2 Community WEST RIDGE ZipCode 60659 ZipCode Community  West Ridge
# Area Number 13 Community NORTH PARK ZipCode 60659 ZipCode Community North Park
# Area Number 77 Community EDGEWATER ZipCode 60660 ZipCode Community Edgewater
# Area Number 28 Community NEAR WEST SIDE ZipCode 60661 ZipCode Community  Near West Side
# Area Number 32 Community LOOP ZipCode 60661 ZipCode Community Loop
# Area Number 28 Community NEAR WEST SIDE ZipCode 60664 ZipCode Community Near West Side
# Area Number 76 Community OHARE ZipCode 60666 ZipCode Community OHare
# Area Number 28 Community NEAR WEST SIDE ZipCode 60680 ZipCode Community Near West Side
# Area Number 28 Community NEAR WEST SIDE ZipCode 60681 ZipCode Community Near West Side
# [1, 'ROGERS PARK', 60626]
# [2, 'WEST RIDGE', 60645]
# [2, 'WEST RIDGE', 60659]
# [3, 'UPTOWN', 60613]
# [3, 'UPTOWN', 60640]
# [4, 'LINCOLN SQUARE', 60625]
# [4, 'LINCOLN SQUARE', 60640]
# [5, 'NORTH CENTER', 60613]
# [5, 'NORTH CENTER', 60618]
# [5, 'NORTH CENTER', 60657]
# [6, 'LAKE VIEW', 60613]
# [6, 'LAKE VIEW', 60657]
# [7, 'LINCOLN PARK', 60614]
# [8, 'NEAR NORTH SIDE', 60610]
# [8, 'NEAR NORTH SIDE', 60611]
# [8, 'NEAR NORTH SIDE', 60622]
# [9, 'EDISON PARK', 60631]
# [10, 'NORWOOD PARK', 60631]
# [10, 'NORWOOD PARK', 60646]
# [11, 'JEFFERSON PARK', 60630]
# [11, 'JEFFERSON PARK', 60646]
# [12, 'FOREST GLEN', 60630]
# [12, 'FOREST GLEN', 60646]
# [13, 'NORTH PARK', 60625]
# [13, 'NORTH PARK', 60646]
# [13, 'NORTH PARK', 60659]
# [14, 'ALBANY PARK', 60625]
# [14, 'ALBANY PARK', 60630]
# [15, 'PORTAGE PARK', 60630]
# [15, 'PORTAGE PARK', 60634]
# [15, 'PORTAGE PARK', 60641]
# [16, 'IRVING PARK', 60618]
# [16, 'IRVING PARK', 60630]
# [16, 'IRVING PARK', 60641]
# [17, 'DUNNING', 60634]
# [17, 'DUNNING', 60635]
# [18, 'MONTCLARE', 60634]
# [18, 'MONTCLARE', 60635]
# [19, 'BELMONT CRAGIN', 60634]
# [19, 'BELMONT CRAGIN', 60635]
# [19, 'BELMONT CRAGIN', 60639]
# [19, 'BELMONT CRAGIN', 60641]
# [20, 'HERMOSA', 60639]
# [20, 'HERMOSA', 60641]
# [20, 'HERMOSA', 60647]
# [21, 'AVONDALE', 60618]
# [21, 'AVONDALE', 60641]
# [22, 'LOGAN SQUARE', 60614]
# [22, 'LOGAN SQUARE', 60622]
# [22, 'LOGAN SQUARE', 60639]
# [22, 'LOGAN SQUARE', 60647]
# [23, 'HUMBOLDT PARK', 60622]
# [23, 'HUMBOLDT PARK', 60624]
# [23, 'HUMBOLDT PARK', 60639]
# [23, 'HUMBOLDT PARK', 60647]
# [23, 'HUMBOLDT PARK', 60651]
# [24, 'WEST TOWN', 60612]
# [24, 'WEST TOWN', 60622]
# [24, 'WEST TOWN', 60647]
# [25, 'AUSTIN', 60635]
# [25, 'AUSTIN', 60639]
# [25, 'AUSTIN', 60644]
# [25, 'AUSTIN', 60651]
# [26, 'WEST GARFIELD PARK', 60624]
# [27, 'EAST GARFIELD PARK', 60624]
# [28, 'NEAR WEST SIDE', 60606]
# [28, 'NEAR WEST SIDE', 60607]
# [28, 'NEAR WEST SIDE', 60608]
# [28, 'NEAR WEST SIDE', 60610]
# [28, 'NEAR WEST SIDE', 60612]
# [28, 'NEAR WEST SIDE', 60661]
# [28, 'NEAR WEST SIDE', 60664]
# [28, 'NEAR WEST SIDE', 60680]
# [28, 'NEAR WEST SIDE', 60681]
# [29, 'NORTH LAWNDALE', 60608]
# [29, 'NORTH LAWNDALE', 60623]
# [29, 'NORTH LAWNDALE', 60624]
# [30, 'SOUTH LAWNDALE', 60608]
# [30, 'SOUTH LAWNDALE', 60623]
# [31, 'LOWER WEST SIDE', 60608]
# [31, 'LOWER WEST SIDE', 60616]
# [32, 'LOOP', 60601]
# [32, 'LOOP', 60602]
# [32, 'LOOP', 60603]
# [32, 'LOOP', 60604]
# [32, 'LOOP', 60605]
# [32, 'LOOP', 60606]
# [32, 'LOOP', 60607]
# [32, 'LOOP', 60661]
# [33, 'NEAR SOUTH SIDE', 60605]
# [33, 'NEAR SOUTH SIDE', 60607]
# [33, 'NEAR SOUTH SIDE', 60616]
# [34, 'ARMOUR SQUARE', 60609]
# [34, 'ARMOUR SQUARE', 60616]
# [35, 'DOUGLAS', 60609]
# [35, 'DOUGLAS', 60616]
# [35, 'DOUGLAS', 60653]
# [36, 'OAKLAND', 60653]
# [37, 'FULLER PARK', 60609]
# [38, 'GRAND BOULEVARD', 60609]
# [38, 'GRAND BOULEVARD', 60615]
# [38, 'GRAND BOULEVARD', 60653]
# [39, 'KENWOOD', 60615]
# [39, 'KENWOOD', 60653]
# [40, 'WASHINGTON PARK', 60609]
# [40, 'WASHINGTON PARK', 60615]
# [40, 'WASHINGTON PARK', 60621]
# [40, 'WASHINGTON PARK', 60637]
# [41, 'HYDE PARK', 60615]
# [41, 'HYDE PARK', 60637]
# [42, 'WOODLAWN', 60637]
# [43, 'SOUTH SHORE', 60619]
# [43, 'SOUTH SHORE', 60637]
# [43, 'SOUTH SHORE', 60649]
# [44, 'CHATHAM', 60619]
# [44, 'CHATHAM', 60620]
# [45, 'AVALON PARK', 60617]
# [45, 'AVALON PARK', 60619]
# [46, 'SOUTH CHICAGO', 60617]
# [47, 'BURNSIDE', 60619]
# [48, 'CALUMET HEIGHTS', 60617]
# [48, 'CALUMET HEIGHTS', 60619]
# [49, 'ROSELAND', 60619]
# [49, 'ROSELAND', 60620]
# [49, 'ROSELAND', 60628]
# [50, 'PULLMAN', 60628]
# [51, 'SOUTH DEERING', 60617]
# [51, 'SOUTH DEERING', 60633]
# [52, 'EAST SIDE', 60617]
# [53, 'WEST PULLMAN', 60628]
# [53, 'WEST PULLMAN', 60643]
# [55, 'HEGEWISCH', 60633]
# [56, 'GARFIELD RIDGE', 60629]
# [56, 'GARFIELD RIDGE', 60632]
# [56, 'GARFIELD RIDGE', 60638]
# [57, 'ARCHER HEIGHTS', 60632]
# [58, 'BRIGHTON PARK', 60632]
# [59, 'MCKINLEY PARK', 60608]
# [59, 'MCKINLEY PARK', 60609]
# [60, 'BRIDGEPORT', 60608]
# [60, 'BRIDGEPORT', 60609]
# [60, 'BRIDGEPORT', 60616]
# [61, 'NEW CITY', 60609]
# [62, 'WEST ELSDON', 60629]
# [62, 'WEST ELSDON', 60632]
# [63, 'GAGE PARK', 60609]
# [63, 'GAGE PARK', 60629]
# [63, 'GAGE PARK', 60632]
# [63, 'GAGE PARK', 60636]
# [64, 'CLEARING', 60629]
# [64, 'CLEARING', 60638]
# [65, 'WEST LAWN', 60629]
# [66, 'CHICAGO LAWN', 60629]
# [66, 'CHICAGO LAWN', 60636]
# [67, 'WEST ENGLEWOOD', 60636]
# [68, 'ENGLEWOOD', 60621]
# [69, 'GREATER GRAND CROSSING', 60619]
# [69, 'GREATER GRAND CROSSING', 60620]
# [69, 'GREATER GRAND CROSSING', 60621]
# [69, 'GREATER GRAND CROSSING', 60637]
# [70, 'ASHBURN', 60652]
# [71, 'AUBURN GRESHAM', 60620]
# [72, 'BEVERLY', 60620]
# [72, 'BEVERLY', 60642]
# [72, 'BEVERLY', 60643]
# [72, 'BEVERLY', 60655]
# [73, 'WASHINGTON HEIGHTS', 60620]
# [73, 'WASHINGTON HEIGHTS', 60628]
# [73, 'WASHINGTON HEIGHTS', 60643]
# [74, 'MOUNT GREENWOOD', 60655]
# [75, 'MORGAN PARK', 60643]
# [75, 'MORGAN PARK', 60655]
# [76, 'OHARE', 60656]
# [76, 'OHARE', 60666]
# [77, 'EDGEWATER', 60640]
# [77, 'EDGEWATER', 60660]
# 176

# %%
import psycopg2 as pg
from psycopg2 import Error
from datetime import date
import numpy as np

try:
    conn = pg.connect("dbname=chicago_business_intelligence user=postgres password=root")

    cursor = conn.cursor()
    
    drop_sql_query = '''drop table if exists community_area_zipcode;'''
    cursor.execute(drop_sql_query)
    
    
    # SQL query to create a new table
    create_table_query = '''CREATE TABLE IF NOT EXISTS "community_area_zipcode" ("id"   SERIAL , 
    "communityAreaNumber" BIGINT, "communityAreaName" VARCHAR(255), 
    "communityAreaZipCode" VARCHAR(255), 
    "createdAt" TIMESTAMP WITH TIME ZONE NOT NULL, 
    "updatedAt" TIMESTAMP WITH TIME ZONE NOT NULL, 
    PRIMARY KEY ("id")
    );'''
    # Execute a command: this creates a new table
    cursor.execute(create_table_query)
    
    for i in range(len(data)):
        print(data[i])
        
        createdAt = date.today()
        updatedAt = date.today()

        insert_query = '''INSERT INTO community_area_zipcode ("communityAreaNumber", 
        "communityAreaName", "communityAreaZipCode", "createdAt", "updatedAt") VALUES (%s, %s, %s, %s, %s);'''
        areaNumber, community, zipCode = data[i]
        print("here i am")
        print(areaNumber.dtype)
        item_tuple = (int(areaNumber), community, str(zipCode), createdAt, updatedAt)
        print(item_tuple)
        cursor.execute(insert_query, item_tuple)
    
    
    conn.commit()
    print("Table created successfully in PostgreSQL ")

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if conn:
        cursor.close()
        conn.close()
        print("PostgreSQL connection is closed")
# Out:
# [1, 'ROGERS PARK', 60626]
# here i am
# int64
# (1, 'ROGERS PARK', '60626', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [2, 'WEST RIDGE', 60645]
# here i am
# int64
# (2, 'WEST RIDGE', '60645', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [2, 'WEST RIDGE', 60659]
# here i am
# int64
# (2, 'WEST RIDGE', '60659', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [3, 'UPTOWN', 60613]
# here i am
# int64
# (3, 'UPTOWN', '60613', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [3, 'UPTOWN', 60640]
# here i am
# int64
# (3, 'UPTOWN', '60640', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [4, 'LINCOLN SQUARE', 60625]
# here i am
# int64
# (4, 'LINCOLN SQUARE', '60625', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [4, 'LINCOLN SQUARE', 60640]
# here i am
# int64
# (4, 'LINCOLN SQUARE', '60640', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [5, 'NORTH CENTER', 60613]
# here i am
# int64
# (5, 'NORTH CENTER', '60613', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [5, 'NORTH CENTER', 60618]
# here i am
# int64
# (5, 'NORTH CENTER', '60618', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [5, 'NORTH CENTER', 60657]
# here i am
# int64
# (5, 'NORTH CENTER', '60657', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [6, 'LAKE VIEW', 60613]
# here i am
# int64
# (6, 'LAKE VIEW', '60613', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [6, 'LAKE VIEW', 60657]
# here i am
# int64
# (6, 'LAKE VIEW', '60657', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [7, 'LINCOLN PARK', 60614]
# here i am
# int64
# (7, 'LINCOLN PARK', '60614', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [8, 'NEAR NORTH SIDE', 60610]
# here i am
# int64
# (8, 'NEAR NORTH SIDE', '60610', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [8, 'NEAR NORTH SIDE', 60611]
# here i am
# int64
# (8, 'NEAR NORTH SIDE', '60611', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [8, 'NEAR NORTH SIDE', 60622]
# here i am
# int64
# (8, 'NEAR NORTH SIDE', '60622', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [9, 'EDISON PARK', 60631]
# here i am
# int64
# (9, 'EDISON PARK', '60631', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [10, 'NORWOOD PARK', 60631]
# here i am
# int64
# (10, 'NORWOOD PARK', '60631', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [10, 'NORWOOD PARK', 60646]
# here i am
# int64
# (10, 'NORWOOD PARK', '60646', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [11, 'JEFFERSON PARK', 60630]
# here i am
# int64
# (11, 'JEFFERSON PARK', '60630', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [11, 'JEFFERSON PARK', 60646]
# here i am
# int64
# (11, 'JEFFERSON PARK', '60646', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [12, 'FOREST GLEN', 60630]
# here i am
# int64
# (12, 'FOREST GLEN', '60630', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [12, 'FOREST GLEN', 60646]
# here i am
# int64
# (12, 'FOREST GLEN', '60646', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [13, 'NORTH PARK', 60625]
# here i am
# int64
# (13, 'NORTH PARK', '60625', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [13, 'NORTH PARK', 60646]
# here i am
# int64
# (13, 'NORTH PARK', '60646', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [13, 'NORTH PARK', 60659]
# here i am
# int64
# (13, 'NORTH PARK', '60659', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [14, 'ALBANY PARK', 60625]
# here i am
# int64
# (14, 'ALBANY PARK', '60625', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [14, 'ALBANY PARK', 60630]
# here i am
# int64
# (14, 'ALBANY PARK', '60630', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [15, 'PORTAGE PARK', 60630]
# here i am
# int64
# (15, 'PORTAGE PARK', '60630', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [15, 'PORTAGE PARK', 60634]
# here i am
# int64
# (15, 'PORTAGE PARK', '60634', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [15, 'PORTAGE PARK', 60641]
# here i am
# int64
# (15, 'PORTAGE PARK', '60641', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [16, 'IRVING PARK', 60618]
# here i am
# int64
# (16, 'IRVING PARK', '60618', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [16, 'IRVING PARK', 60630]
# here i am
# int64
# (16, 'IRVING PARK', '60630', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [16, 'IRVING PARK', 60641]
# here i am
# int64
# (16, 'IRVING PARK', '60641', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [17, 'DUNNING', 60634]
# here i am
# int64
# (17, 'DUNNING', '60634', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [17, 'DUNNING', 60635]
# here i am
# int64
# (17, 'DUNNING', '60635', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [18, 'MONTCLARE', 60634]
# here i am
# int64
# (18, 'MONTCLARE', '60634', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [18, 'MONTCLARE', 60635]
# here i am
# int64
# (18, 'MONTCLARE', '60635', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [19, 'BELMONT CRAGIN', 60634]
# here i am
# int64
# (19, 'BELMONT CRAGIN', '60634', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [19, 'BELMONT CRAGIN', 60635]
# here i am
# int64
# (19, 'BELMONT CRAGIN', '60635', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [19, 'BELMONT CRAGIN', 60639]
# here i am
# int64
# (19, 'BELMONT CRAGIN', '60639', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [19, 'BELMONT CRAGIN', 60641]
# here i am
# int64
# (19, 'BELMONT CRAGIN', '60641', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [20, 'HERMOSA', 60639]
# here i am
# int64
# (20, 'HERMOSA', '60639', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [20, 'HERMOSA', 60641]
# here i am
# int64
# (20, 'HERMOSA', '60641', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [20, 'HERMOSA', 60647]
# here i am
# int64
# (20, 'HERMOSA', '60647', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [21, 'AVONDALE', 60618]
# here i am
# int64
# (21, 'AVONDALE', '60618', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [21, 'AVONDALE', 60641]
# here i am
# int64
# (21, 'AVONDALE', '60641', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [22, 'LOGAN SQUARE', 60614]
# here i am
# int64
# (22, 'LOGAN SQUARE', '60614', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [22, 'LOGAN SQUARE', 60622]
# here i am
# int64
# (22, 'LOGAN SQUARE', '60622', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [22, 'LOGAN SQUARE', 60639]
# here i am
# int64
# (22, 'LOGAN SQUARE', '60639', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [22, 'LOGAN SQUARE', 60647]
# here i am
# int64
# (22, 'LOGAN SQUARE', '60647', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [23, 'HUMBOLDT PARK', 60622]
# here i am
# int64
# (23, 'HUMBOLDT PARK', '60622', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [23, 'HUMBOLDT PARK', 60624]
# here i am
# int64
# (23, 'HUMBOLDT PARK', '60624', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [23, 'HUMBOLDT PARK', 60639]
# here i am
# int64
# (23, 'HUMBOLDT PARK', '60639', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [23, 'HUMBOLDT PARK', 60647]
# here i am
# int64
# (23, 'HUMBOLDT PARK', '60647', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [23, 'HUMBOLDT PARK', 60651]
# here i am
# int64
# (23, 'HUMBOLDT PARK', '60651', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [24, 'WEST TOWN', 60612]
# here i am
# int64
# (24, 'WEST TOWN', '60612', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [24, 'WEST TOWN', 60622]
# here i am
# int64
# (24, 'WEST TOWN', '60622', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [24, 'WEST TOWN', 60647]
# here i am
# int64
# (24, 'WEST TOWN', '60647', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [25, 'AUSTIN', 60635]
# here i am
# int64
# (25, 'AUSTIN', '60635', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [25, 'AUSTIN', 60639]
# here i am
# int64
# (25, 'AUSTIN', '60639', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [25, 'AUSTIN', 60644]
# here i am
# int64
# (25, 'AUSTIN', '60644', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [25, 'AUSTIN', 60651]
# here i am
# int64
# (25, 'AUSTIN', '60651', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [26, 'WEST GARFIELD PARK', 60624]
# here i am
# int64
# (26, 'WEST GARFIELD PARK', '60624', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [27, 'EAST GARFIELD PARK', 60624]
# here i am
# int64
# (27, 'EAST GARFIELD PARK', '60624', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [28, 'NEAR WEST SIDE', 60606]
# here i am
# int64
# (28, 'NEAR WEST SIDE', '60606', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [28, 'NEAR WEST SIDE', 60607]
# here i am
# int64
# (28, 'NEAR WEST SIDE', '60607', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [28, 'NEAR WEST SIDE', 60608]
# here i am
# int64
# (28, 'NEAR WEST SIDE', '60608', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [28, 'NEAR WEST SIDE', 60610]
# here i am
# int64
# (28, 'NEAR WEST SIDE', '60610', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [28, 'NEAR WEST SIDE', 60612]
# here i am
# int64
# (28, 'NEAR WEST SIDE', '60612', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [28, 'NEAR WEST SIDE', 60661]
# here i am
# int64
# (28, 'NEAR WEST SIDE', '60661', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [28, 'NEAR WEST SIDE', 60664]
# here i am
# int64
# (28, 'NEAR WEST SIDE', '60664', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [28, 'NEAR WEST SIDE', 60680]
# here i am
# int64
# (28, 'NEAR WEST SIDE', '60680', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [28, 'NEAR WEST SIDE', 60681]
# here i am
# int64
# (28, 'NEAR WEST SIDE', '60681', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [29, 'NORTH LAWNDALE', 60608]
# here i am
# int64
# (29, 'NORTH LAWNDALE', '60608', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [29, 'NORTH LAWNDALE', 60623]
# here i am
# int64
# (29, 'NORTH LAWNDALE', '60623', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [29, 'NORTH LAWNDALE', 60624]
# here i am
# int64
# (29, 'NORTH LAWNDALE', '60624', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [30, 'SOUTH LAWNDALE', 60608]
# here i am
# int64
# (30, 'SOUTH LAWNDALE', '60608', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [30, 'SOUTH LAWNDALE', 60623]
# here i am
# int64
# (30, 'SOUTH LAWNDALE', '60623', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [31, 'LOWER WEST SIDE', 60608]
# here i am
# int64
# (31, 'LOWER WEST SIDE', '60608', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [31, 'LOWER WEST SIDE', 60616]
# here i am
# int64
# (31, 'LOWER WEST SIDE', '60616', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [32, 'LOOP', 60601]
# here i am
# int64
# (32, 'LOOP', '60601', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [32, 'LOOP', 60602]
# here i am
# int64
# (32, 'LOOP', '60602', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [32, 'LOOP', 60603]
# here i am
# int64
# (32, 'LOOP', '60603', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [32, 'LOOP', 60604]
# here i am
# int64
# (32, 'LOOP', '60604', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [32, 'LOOP', 60605]
# here i am
# int64
# (32, 'LOOP', '60605', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [32, 'LOOP', 60606]
# here i am
# int64
# (32, 'LOOP', '60606', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [32, 'LOOP', 60607]
# here i am
# int64
# (32, 'LOOP', '60607', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [32, 'LOOP', 60661]
# here i am
# int64
# (32, 'LOOP', '60661', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [33, 'NEAR SOUTH SIDE', 60605]
# here i am
# int64
# (33, 'NEAR SOUTH SIDE', '60605', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [33, 'NEAR SOUTH SIDE', 60607]
# here i am
# int64
# (33, 'NEAR SOUTH SIDE', '60607', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [33, 'NEAR SOUTH SIDE', 60616]
# here i am
# int64
# (33, 'NEAR SOUTH SIDE', '60616', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [34, 'ARMOUR SQUARE', 60609]
# here i am
# int64
# (34, 'ARMOUR SQUARE', '60609', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [34, 'ARMOUR SQUARE', 60616]
# here i am
# int64
# (34, 'ARMOUR SQUARE', '60616', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [35, 'DOUGLAS', 60609]
# here i am
# int64
# (35, 'DOUGLAS', '60609', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [35, 'DOUGLAS', 60616]
# here i am
# int64
# (35, 'DOUGLAS', '60616', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [35, 'DOUGLAS', 60653]
# here i am
# int64
# (35, 'DOUGLAS', '60653', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [36, 'OAKLAND', 60653]
# here i am
# int64
# (36, 'OAKLAND', '60653', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [37, 'FULLER PARK', 60609]
# here i am
# int64
# (37, 'FULLER PARK', '60609', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [38, 'GRAND BOULEVARD', 60609]
# here i am
# int64
# (38, 'GRAND BOULEVARD', '60609', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [38, 'GRAND BOULEVARD', 60615]
# here i am
# int64
# (38, 'GRAND BOULEVARD', '60615', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [38, 'GRAND BOULEVARD', 60653]
# here i am
# int64
# (38, 'GRAND BOULEVARD', '60653', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [39, 'KENWOOD', 60615]
# here i am
# int64
# (39, 'KENWOOD', '60615', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [39, 'KENWOOD', 60653]
# here i am
# int64
# (39, 'KENWOOD', '60653', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [40, 'WASHINGTON PARK', 60609]
# here i am
# int64
# (40, 'WASHINGTON PARK', '60609', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [40, 'WASHINGTON PARK', 60615]
# here i am
# int64
# (40, 'WASHINGTON PARK', '60615', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [40, 'WASHINGTON PARK', 60621]
# here i am
# int64
# (40, 'WASHINGTON PARK', '60621', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [40, 'WASHINGTON PARK', 60637]
# here i am
# int64
# (40, 'WASHINGTON PARK', '60637', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [41, 'HYDE PARK', 60615]
# here i am
# int64
# (41, 'HYDE PARK', '60615', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [41, 'HYDE PARK', 60637]
# here i am
# int64
# (41, 'HYDE PARK', '60637', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [42, 'WOODLAWN', 60637]
# here i am
# int64
# (42, 'WOODLAWN', '60637', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [43, 'SOUTH SHORE', 60619]
# here i am
# int64
# (43, 'SOUTH SHORE', '60619', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [43, 'SOUTH SHORE', 60637]
# here i am
# int64
# (43, 'SOUTH SHORE', '60637', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [43, 'SOUTH SHORE', 60649]
# here i am
# int64
# (43, 'SOUTH SHORE', '60649', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [44, 'CHATHAM', 60619]
# here i am
# int64
# (44, 'CHATHAM', '60619', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [44, 'CHATHAM', 60620]
# here i am
# int64
# (44, 'CHATHAM', '60620', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [45, 'AVALON PARK', 60617]
# here i am
# int64
# (45, 'AVALON PARK', '60617', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [45, 'AVALON PARK', 60619]
# here i am
# int64
# (45, 'AVALON PARK', '60619', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [46, 'SOUTH CHICAGO', 60617]
# here i am
# int64
# (46, 'SOUTH CHICAGO', '60617', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [47, 'BURNSIDE', 60619]
# here i am
# int64
# (47, 'BURNSIDE', '60619', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [48, 'CALUMET HEIGHTS', 60617]
# here i am
# int64
# (48, 'CALUMET HEIGHTS', '60617', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [48, 'CALUMET HEIGHTS', 60619]
# here i am
# int64
# (48, 'CALUMET HEIGHTS', '60619', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [49, 'ROSELAND', 60619]
# here i am
# int64
# (49, 'ROSELAND', '60619', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [49, 'ROSELAND', 60620]
# here i am
# int64
# (49, 'ROSELAND', '60620', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [49, 'ROSELAND', 60628]
# here i am
# int64
# (49, 'ROSELAND', '60628', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [50, 'PULLMAN', 60628]
# here i am
# int64
# (50, 'PULLMAN', '60628', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [51, 'SOUTH DEERING', 60617]
# here i am
# int64
# (51, 'SOUTH DEERING', '60617', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [51, 'SOUTH DEERING', 60633]
# here i am
# int64
# (51, 'SOUTH DEERING', '60633', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [52, 'EAST SIDE', 60617]
# here i am
# int64
# (52, 'EAST SIDE', '60617', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [53, 'WEST PULLMAN', 60628]
# here i am
# int64
# (53, 'WEST PULLMAN', '60628', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [53, 'WEST PULLMAN', 60643]
# here i am
# int64
# (53, 'WEST PULLMAN', '60643', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [55, 'HEGEWISCH', 60633]
# here i am
# int64
# (55, 'HEGEWISCH', '60633', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [56, 'GARFIELD RIDGE', 60629]
# here i am
# int64
# (56, 'GARFIELD RIDGE', '60629', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [56, 'GARFIELD RIDGE', 60632]
# here i am
# int64
# (56, 'GARFIELD RIDGE', '60632', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [56, 'GARFIELD RIDGE', 60638]
# here i am
# int64
# (56, 'GARFIELD RIDGE', '60638', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [57, 'ARCHER HEIGHTS', 60632]
# here i am
# int64
# (57, 'ARCHER HEIGHTS', '60632', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [58, 'BRIGHTON PARK', 60632]
# here i am
# int64
# (58, 'BRIGHTON PARK', '60632', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [59, 'MCKINLEY PARK', 60608]
# here i am
# int64
# (59, 'MCKINLEY PARK', '60608', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [59, 'MCKINLEY PARK', 60609]
# here i am
# int64
# (59, 'MCKINLEY PARK', '60609', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [60, 'BRIDGEPORT', 60608]
# here i am
# int64
# (60, 'BRIDGEPORT', '60608', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [60, 'BRIDGEPORT', 60609]
# here i am
# int64
# (60, 'BRIDGEPORT', '60609', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [60, 'BRIDGEPORT', 60616]
# here i am
# int64
# (60, 'BRIDGEPORT', '60616', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [61, 'NEW CITY', 60609]
# here i am
# int64
# (61, 'NEW CITY', '60609', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [62, 'WEST ELSDON', 60629]
# here i am
# int64
# (62, 'WEST ELSDON', '60629', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [62, 'WEST ELSDON', 60632]
# here i am
# int64
# (62, 'WEST ELSDON', '60632', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [63, 'GAGE PARK', 60609]
# here i am
# int64
# (63, 'GAGE PARK', '60609', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [63, 'GAGE PARK', 60629]
# here i am
# int64
# (63, 'GAGE PARK', '60629', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [63, 'GAGE PARK', 60632]
# here i am
# int64
# (63, 'GAGE PARK', '60632', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [63, 'GAGE PARK', 60636]
# here i am
# int64
# (63, 'GAGE PARK', '60636', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [64, 'CLEARING', 60629]
# here i am
# int64
# (64, 'CLEARING', '60629', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [64, 'CLEARING', 60638]
# here i am
# int64
# (64, 'CLEARING', '60638', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [65, 'WEST LAWN', 60629]
# here i am
# int64
# (65, 'WEST LAWN', '60629', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [66, 'CHICAGO LAWN', 60629]
# here i am
# int64
# (66, 'CHICAGO LAWN', '60629', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [66, 'CHICAGO LAWN', 60636]
# here i am
# int64
# (66, 'CHICAGO LAWN', '60636', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [67, 'WEST ENGLEWOOD', 60636]
# here i am
# int64
# (67, 'WEST ENGLEWOOD', '60636', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [68, 'ENGLEWOOD', 60621]
# here i am
# int64
# (68, 'ENGLEWOOD', '60621', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [69, 'GREATER GRAND CROSSING', 60619]
# here i am
# int64
# (69, 'GREATER GRAND CROSSING', '60619', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [69, 'GREATER GRAND CROSSING', 60620]
# here i am
# int64
# (69, 'GREATER GRAND CROSSING', '60620', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [69, 'GREATER GRAND CROSSING', 60621]
# here i am
# int64
# (69, 'GREATER GRAND CROSSING', '60621', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [69, 'GREATER GRAND CROSSING', 60637]
# here i am
# int64
# (69, 'GREATER GRAND CROSSING', '60637', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [70, 'ASHBURN', 60652]
# here i am
# int64
# (70, 'ASHBURN', '60652', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [71, 'AUBURN GRESHAM', 60620]
# here i am
# int64
# (71, 'AUBURN GRESHAM', '60620', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [72, 'BEVERLY', 60620]
# here i am
# int64
# (72, 'BEVERLY', '60620', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [72, 'BEVERLY', 60642]
# here i am
# int64
# (72, 'BEVERLY', '60642', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [72, 'BEVERLY', 60643]
# here i am
# int64
# (72, 'BEVERLY', '60643', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [72, 'BEVERLY', 60655]
# here i am
# int64
# (72, 'BEVERLY', '60655', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [73, 'WASHINGTON HEIGHTS', 60620]
# here i am
# int64
# (73, 'WASHINGTON HEIGHTS', '60620', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [73, 'WASHINGTON HEIGHTS', 60628]
# here i am
# int64
# (73, 'WASHINGTON HEIGHTS', '60628', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [73, 'WASHINGTON HEIGHTS', 60643]
# here i am
# int64
# (73, 'WASHINGTON HEIGHTS', '60643', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [74, 'MOUNT GREENWOOD', 60655]
# here i am
# int64
# (74, 'MOUNT GREENWOOD', '60655', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [75, 'MORGAN PARK', 60643]
# here i am
# int64
# (75, 'MORGAN PARK', '60643', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [75, 'MORGAN PARK', 60655]
# here i am
# int64
# (75, 'MORGAN PARK', '60655', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [76, 'OHARE', 60656]
# here i am
# int64
# (76, 'OHARE', '60656', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [76, 'OHARE', 60666]
# here i am
# int64
# (76, 'OHARE', '60666', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [77, 'EDGEWATER', 60640]
# here i am
# int64
# (77, 'EDGEWATER', '60640', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# [77, 'EDGEWATER', 60660]
# here i am
# int64
# (77, 'EDGEWATER', '60660', datetime.date(2021, 11, 21), datetime.date(2021, 11, 21))
# Table created successfully in PostgreSQL
# PostgreSQL connection is closed
